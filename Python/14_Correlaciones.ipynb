# %% [markdown]
# <center><img src="https://drive.google.com/uc?id=1uDO4E0lab13rGc6vK1bPALwfghorjqkV"></center>

# %% [markdown]
# #CORRELACIÓN
#
# La correlación es una medida estadística que explica la relación lineal entre dos variables. Es decir, permite saber si dos variables cambian conjuntamente a una tasa constante.
#
# La correlación entre dos variables se expresa en un coeficiente: el coeficiente de correlación $r$  (con un rango $-1 < r <1$), que indica la intensidad de la relación y puede visualizarse en una **gráfica de dispersión**.
# Cada punto en la gráfica corresponde a un par de datos, por ejemplo, podemos ubicar en el eje $x$ la temperatura y, en el eje $y$, el volumen de un gas para ver si existe relación entre estas variables.
#
#
# <center><img src=https://drive.google.com/uc?id=1PLPt4NrZKKswQa4yDiEUjgeENMksG05v></center>

# %% [markdown]
# ## Valores del coeficiente de correlación
# El coeficiente de correlación r es un valor sin unidades entre -1 y 1. La significancia estadística se indica con un valor p. Por lo tanto, usualmente las correlaciones se escriben con dos números clave: r y p.
#
# Cuanto r está más cerca a cero, más débil es la relación lineal.
# Los valores de r positivos indican una correlación positiva, en la que los valores de ambas variables tienden a incrementarse juntos.
# Los valores de r negativos indican una correlación negativa, en la que los valores de una variable tienden a incrementarse mientras que los valores de la otra variable descienden.
# Los valores 1 y -1 representan una correlación "perfecta" positiva y negativa, respectivamente. Dos variables perfectamente correlacionadas cambian conjuntamente a una tasa fija. Decimos que tienen una relación linear; cuando representados en un gráfico de dispersión, todos los puntos correspondientes a los datos pueden conectarse con una misma línea recta.

# %% [markdown]
# ##Propiedades de $r$
# * El valor de $r$ no depende de cuál de las dos variables es $x$ o es $y$.
# * El valor de $r$ es independiente de las unidades en cuales se midan $x$ e $y$.
# * $-1 <= r <= 1$
# * $r = 1$ si y sólo si todos los pares $(x,y)$ quedan en una línea recta con pendiente positiva, y $r = -1$ si y sólo si los pares $(x,y)$ quedan en una línea recta con pendiente negativa.

# %% [markdown]
# ###Actividad: ¿Estudiar aumenta tu nota?
#
# Analizar correlación entre la calificación y horas de estudio semanales
#
# Fuente de datos: [qualifications.xlsx](https://docs.google.com/spreadsheets/d/1SAkwsJwxfW3Od8dOuJucSKrI3Da2SEMO/edit?usp=sharing&ouid=101045962169417788523&rtpof=true&sd=true) (generado por Mockaroo)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
df = pd.read_excel("/content/drive/MyDrive/Big Data 202401 - Material del curso/General/8 - Estadística Descriptiva/qualifications.xlsx")
df
# Out:
#     first_name  last_name  weekly_study_hours  is_employed  age  gender  \
# 0       Buiron    Ferrone                1.00            1   24    Male
# 1        Gunar     Champe                1.00            1   22    Male
# 2       Henrie  Goodboddy                1.01            0   26  Female
# 3        Elset   Moxstead                1.03            0   26  Female
# 4      Felicio     Cocher                1.07            0   25    Male
# ..         ...        ...                 ...          ...  ...     ...
# 995       Riva    Cantera               30.00            0   27  Female
# 996      Nanny     Skates               30.00            1   18  Female
# 997  Valentine   Mariolle               30.00            1   26    Male
# 998    Loralee      Niche               30.00            0   26  Female
# 999     Gasper     Wilden               29.09            0   26    Male
#
#      qualification
# 0               39
# 1               34
# 2               34
# 3               40
# ...

# %%
df.plot(kind="scatter", y="qualification", x="weekly_study_hours")
# Out:
# <Axes: xlabel='weekly_study_hours', ylabel='qualification'>

# %% [markdown]
# **Una relación fuerte no implica necesariamente una relación causa-efecto**. Simplemente nos está indicando que ambas variables nos están entregando la misma información dentro de cierto rango. Deberíamos hacer un estudio más detallado de ambas variables antes de decidir eliminar alguna de las dos de nuestro input de datos.
#
# En el siguiente ejemplo, podemos observar el comportamiento idéntico de dos variables que no se relacionan ni influyen de ninguna forma una sobre la otra.
#
# <center><img src=https://drive.google.com/uc?id=1PmNhN3GRJ72jivatXLwHGtvvERHI7eAG><em>Imagen de Spurious Correlations</em></center>

# %% [markdown]
# ## MATERIAL COMPLEMENTARIO
# - [Coeficiente de correlación - Portal de formación estadística](https://www.jmp.com/es_ar/statistics-knowledge-portal/what-is-correlation/correlation-coefficient.html)
# - [Spurious Correlations](https://www.tylervigen.com/spurious-correlations)

# %% [markdown]
# <hr>
# <img src="https://drive.google.com/uc?id=16Fy8ub2YrUHJnQ8W2p3DrVI42b20ncXz" width="400">
#
# **Todos los derechos son reservados por el Programa Codo a Codo perteneciente a la Dirección Agencia de Habilidades para el Futuro del Ministerio de Educación del Gobierno de la Ciudad Autónoma de Buenos Aires. Se encuentra prohibida su venta o comercialización.**
